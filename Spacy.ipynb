# %%
# !pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\Khushi\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script typer.exe is installed in 'C:\Users\Khushi\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script weasel.exe is installed in 'C:\Users\Khushi\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script spacy.exe is installed in 'C:\Users\Khushi\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
# ...

# %%
import spacy

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.3/400.7 MB ? eta -:--:--
#      ---------------------------------------- 0.8/400.7 MB 4.2 MB/s eta 0:01:36
#      ---------------------------------------- 1.0/400.7 MB 1.9 MB/s eta 0:03:35
#      ---------------------------------------- 1.0/400.7 MB 1.9 MB/s eta 0:03:35
#      ---------------------------------------- 1.3/400.7 MB 1.4 MB/s eta 0:04:46
#      ---------------------------------------- 1.3/400.7 MB 1.4 MB/s eta 0:04:46
#      ---------------------------------------- 1.6/400.7 MB 1.0 MB/s eta 0:06:35
#      ---------------------------------------- 1.6/400.7 MB 1.0 MB/s eta 0:06:35
#      -------------------------------------- 1.8/400.7 MB 986.7 kB/s eta 0:06:45
#      ---------------------------------------- 2.1/400.7 MB 1.0 MB/s eta 0:06:38
# ...

# %%
nlp= spacy.load('en_core_web_lg')

# %%
text="khushi want to play cricket"

# %%
for token in text:
    print(token)
# Out:
# k
# h
# u
# s
# h
# i
#
# w
# a
# n
# t
#
# t
# o
#
# p
# l
# a
# y
#
# c
# r
# i
# c
# k
# e
# t

# %%
text=nlp('cost of iphone in india is 1234323')

# %%
for token in text:
    print(token.text)
# Out:
# cost
# of
# iphone
# in
# india
# is
# 1234323

# %% [markdown]
# ### Parts of speech

# %%
for token in text:
    print(token.text,token.pos_)
# Out:
# cost NOUN
# of ADP
# iphone NOUN
# in ADP
# india PROPN
# is AUX
# 1234323 NUM

# %%
s=nlp(u"This is the first sentence. I gave given fullstop please check. Let's study now")
for sentence in s.sents:
    print(sentence)
# Out:
# This is the first sentence.
# I gave given fullstop please check.
# Let's study now

# %% [markdown]
# ## Stop word removal using spacy

# %%
import spacy

# %%
nlp= spacy.load('en_core_web_lg')

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['is'].is_stop
# Out:
# True

# %%
nlp.vocab['of'].is_stop
# Out:
# True

# %% [markdown]
# ## Adding custom words from the lidt of stop words

# %%
nlp.Defaults.stop_words.add('i.e')

# %%
nlp.vocab['i.e'].is_stop=True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %% [markdown]
# ## Removing Custom words from the list of StopWords

# %%
nlp.vocab['i.e'].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('i.e')
nlp.vocab['i.e'].is_stop  =False
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 nlp.Defaults.stop_words.remove('i.e')
#       2 nlp.vocab['i.e'].is_stop=False
#
# KeyError: 'i.e'

# %%
nlp.vocab['i.e'].is_stop
# Out:
# True

# %% [markdown]
# #Removing stopwords from corpus

# %%
txt='Machine learning is a branch of Artificial Intelligence that focuses on developing models and algorithms that let computers learn from data without being explicitly programmed for every task. In simple words, ML teaches the systems to think and understand like humans by learning from the data.'

# %%
txt= txt.replace('\n','')
txt=txt.replace('  ','')
txt=txt.strip()
txt
# Out:
# 'Machine learning is a branch of Artificial Intelligence that focuses on developing models and algorithms that let computers learn from data without being explicitly programmed for every task. In simple words, ML teaches the systems to think and understand like humans by learning from the data.'

# %%
corp=nlp(txt)

# %%
corp
# Out:
# Machine learning is a branch of Artificial Intelligence that focuses on developing models and algorithms that let computers learn from data without being explicitly programmed for every task. In simple words, ML teaches the systems to think and understand like humans by learning from the data.

# %%
stop_words=[]

for token in corp:
    if token.is_stop:
        stop_words.append(token)
print(stop_words)
# Out:
# [is, a, of, that, on, and, that, from, without, being, for, every, In, the, to, and, by, from, the]

# %%
len(stop_words)
# Out:
# 19

# %%
stop_words=set()

for token in corp:
  if token.is_stop:
    stop_words.add(token.text)
print(stop_words)
print(len(stop_words))
# Out:
# {'on', 'for', 'every', 'by', 'from', 'and', 'In', 'being', 'is', 'a', 'the', 'without', 'of', 'to', 'that'}
# 15

# %% [markdown]
# ## Antonym and Synonym

# %%
from nltk.corpus import wordnet

# %%
wordnet.synsets('Book')
# Out:
# [Synset('book.n.01'),
#  Synset('book.n.02'),
#  Synset('record.n.05'),
#  Synset('script.n.01'),
#  Synset('ledger.n.01'),
#  Synset('book.n.06'),
#  Synset('book.n.07'),
#  Synset('koran.n.01'),
#  Synset('bible.n.01'),
#  Synset('book.n.10'),
#  Synset('book.n.11'),
#  Synset('book.v.01'),
#  Synset('reserve.v.04'),
#  Synset('book.v.03'),
#  Synset('book.v.04')]

# %%
wordnet.synsets('good')
# Out:
# [Synset('good.n.01'),
#  Synset('good.n.02'),
#  Synset('good.n.03'),
#  Synset('commodity.n.01'),
#  Synset('good.a.01'),
#  Synset('full.s.06'),
#  Synset('good.a.03'),
#  Synset('estimable.s.02'),
#  Synset('beneficial.s.01'),
#  Synset('good.s.06'),
#  Synset('good.s.07'),
#  Synset('adept.s.01'),
#  Synset('good.s.09'),
#  Synset('dear.s.02'),
#  Synset('dependable.s.04'),
#  Synset('good.s.12'),
#  Synset('good.s.13'),
#  Synset('effective.s.04'),
#  Synset('good.s.15'),
#  Synset('good.s.16'),
#  Synset('good.s.17'),
#  Synset('good.s.18'),
#  Synset('good.s.19'),
#  Synset('good.s.20'),
#  Synset('good.s.21'),
#  Synset('well.r.01'),
#  Synset('thoroughly.r.02')]

# %%
syn=wordnet.synsets('Book')
syn[0].definition()
# Out:
# 'a written work or composition that has been published (printed on pages bound together)'

# %% [markdown]
# ### Printing synonyms

# %%
for syn in wordnet.synsets('car'):
    for lemma in syn.lemmas():

         print(lemma.name())
# Out:
# car
# auto
# automobile
# machine
# motorcar
# car
# railcar
# railway_car
# railroad_car
# car
# gondola
# car
# elevator_car
# cable_car
# car

# %%
synonyms=[]

for syn in wordnet.synsets('car'):
    for lemma in syn.lemmas():
        synonyms.append(lemma.name())
print(synonyms)
# Out:
# ['car', 'auto', 'automobile', 'machine', 'motorcar', 'car', 'railcar', 'railway_car', 'railroad_car', 'car', 'gondola', 'car', 'elevator_car', 'cable_car', 'car']

# %% [markdown]
# ### Print Antonyms

# %%
antonyms=[]

for ant in wordnet.synsets('happy'):
    for lemma in ant.lemmas():
        if lemma.antonyms():
        # synonyms.append(lemma.name())
            print(lemma.antonyms()[0].name())
# Out:
# unhappy
